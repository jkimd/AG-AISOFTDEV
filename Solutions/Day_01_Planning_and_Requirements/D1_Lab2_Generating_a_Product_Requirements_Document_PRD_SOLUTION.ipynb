# %% [markdown]
# # Day 1 - Lab 2: Generating a Product Requirements Document (PRD) (Solution)
#
# **Objective:** Use the structured `day1_user_stories.json` artifact from the previous lab to generate a formal, comprehensive Product Requirements Document (PRD) in markdown format.
#
# **Introduction:**
# This solution notebook demonstrates how to synthesize detailed, low-level requirements (user stories) into a high-level planning document (the PRD). It also introduces the advanced concept of using code (Pydantic models) to define and validate the structure of documentation.
#
# For definitions of key terms used in this lab, please refer to the [GLOSSARY.md](../../GLOSSARY.md).

# %% [markdown]
# ## Step 1: Setup
#
# **Explanation:**
# We begin by setting up our environment and loading the key artifact from Lab 1: `day1_user_stories.json`. The `load_artifact` helper function reads the file content, and `json.loads` parses the JSON string into a Python list of dictionaries, making it ready for use in our prompts.

# %%
import sys
import os
import json

# Add the project's root directory to the Python path to ensure 'utils' can be imported.
try:
    # Assumes the notebook is in 'labs/Day_01_.../'
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
except IndexError:
    # Fallback for different execution environments
    project_root = os.path.abspath(os.path.join(os.getcwd()))

if project_root not in sys.path:
    sys.path.insert(0, project_root)

from utils import setup_llm_client, get_completion, save_artifact, load_artifact, clean_llm_output, recommended_models_table, prompt_enhancer

# Initialize the LLM client. You can change the model here.
client, model_name, api_provider = setup_llm_client(model_name="gemini-2.5-pro")

# Load the artifact from Lab 1
user_stories_data = load_artifact("day1_user_stories.json")
if user_stories_data:
    # Convert to JSON string if it's already a Python object
    if isinstance(user_stories_data, (list, dict)):
        user_stories_str = json.dumps(user_stories_data, indent=2)
    else:
        user_stories_str = user_stories_data
else:
    print("Warning: Could not load user stories. Lab may not function correctly.")
    user_stories_data = []
    user_stories_str = "[]"
# Out:
# 2025-10-27 20:29:57,553 ag_aisoftdev.utils INFO LLM Client configured provider=google model=gemini-2.5-pro latency_ms=None artifacts_path=None

# %%
recommended_models_table()
# Out:
# | Model | Provider | Text | Vision | Image Gen | Image Edit | Audio Transcription | Context Window | Max Output Tokens |
# |---|---|---|---|---|---|---|---|---|
# | Qwen/Qwen-Image | huggingface | ❌ | ❌ | ✅ | ❌ | ❌ | - | - |
# | Qwen/Qwen-Image-Edit | huggingface | ❌ | ❌ | ❌ | ✅ | ❌ | - | - |
# | black-forest-labs/FLUX.1-Kontext-dev | huggingface | ❌ | ❌ | ❌ | ✅ | ❌ | - | - |
# | claude-opus-4-1-20250805 | anthropic | ✅ | ✅ | ❌ | ❌ | ❌ | 200,000 | 100,000 |
# | claude-opus-4-20250514 | anthropic | ✅ | ✅ | ❌ | ❌ | ❌ | 200,000 | 100,000 |
# | claude-sonnet-4-20250514 | anthropic | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 100,000 |
# | dall-e-3 | openai | ❌ | ❌ | ✅ | ❌ | ❌ | - | - |
# | deepseek-ai/DeepSeek-V3.1 | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 128,000 | 100,000 |
# | gemini-1.5-flash | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 8,192 |
# | gemini-1.5-pro | google | ✅ | ✅ | ❌ | ❌ | ❌ | 2,000,000 | 8,192 |
# | gemini-2.0-flash-exp | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,048,576 | 8,192 |
# | gemini-2.0-flash-preview-image-generation | google | ❌ | ❌ | ✅ | ❌ | ❌ | 32,000 | 8,192 |
# | gemini-2.5-flash | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,048,576 | 65,536 |
# | gemini-2.5-flash-image-preview | google | ❌ | ❌ | ✅ | ❌ | ❌ | 32,768 | 32,768 |
# | gemini-2.5-flash-lite | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,048,576 | 65,536 |
# | gemini-2.5-pro | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,048,576 | 65,536 |
# | gemini-live-2.5-flash-preview | google | ❌ | ❌ | ❌ | ❌ | ❌ | 1,048,576 | 8,192 |
# | gpt-4.1 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 32,768 |
# | gpt-4.1-mini | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 32,000 |
# | gpt-4.1-nano | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 32,000 |
# | gpt-4o | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 128,000 | 16,384 |
# | gpt-4o-mini | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 128,000 | 16,384 |
# | gpt-5-2025-08-07 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 400,000 | 128,000 |
# | gpt-5-mini-2025-08-07 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 400,000 | 128,000 |
# | gpt-5-nano-2025-08-07 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 400,000 | 128,000 |
# | meta-llama/Llama-3.3-70B-Instruct | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 8,192 | 4,096 |
# | meta-llama/Llama-4-Maverick-17B-128E-Instruct | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 1,000,000 | 100,000 |
# | meta-llama/Llama-4-Scout-17B-16E-Instruct | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 10,000,000 | 100,000 |
# | mistralai/Mistral-7B-Instruct-v0.3 | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 32,768 | 8,192 |
# | o3 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 200,000 | 100,000 |
# | o4-mini | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 200,000 | 100,000 |
# | stabilityai/stable-diffusion-3.5-large | huggingface | ❌ | ❌ | ✅ | ❌ | ❌ | - | - |
# | tokyotech-llm/Llama-3.1-Swallow-8B-Instruct-v0.5 | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 4,096 | 1,024 |
# | veo-3.0-fast-generate-preview | google | ❌ | ❌ | ❌ | ❌ | ❌ | 1,024 | - |
# | veo-3.0-generate-preview | google | ❌ | ❌ | ❌ | ❌ | ❌ | 1,024 | - |
# | whisper-1 | openai | ❌ | ❌ | ❌ | ❌ | ✅ | - | - |
# '| Model | Provider | Text | Vision | Image Gen | Image Edit | Audio Transcription | Context Window | Max Output Tokens |\n|---|---|---|---|---|---|---|---|---|\n| Qwen/Qwen-Image | huggingface | ❌ | ❌ | ✅ | ❌ | ❌ | - | - |\n| Qwen/Qwen-Image-Edit | huggingface | ❌ | ❌ | ❌ | ✅ | ❌ | - | - |\n| black-forest-labs/FLUX.1-Kontext-dev | huggingface | ❌ | ❌ | ❌ | ✅ | ❌ | - | - |\n| claude-opus-4-1-20250805 | anthropic | ✅ | ✅ | ❌ | ❌ | ❌ | 200,000 | 100,000 |\n| claude-opus-4-20250514 | anthropic | ✅ | ✅ | ❌ | ❌ | ❌ | 200,000 | 100,000 |\n| claude-sonnet-4-20250514 | anthropic | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 100,000 |\n| dall-e-3 | openai | ❌ | ❌ | ✅ | ❌ | ❌ | - | - |\n| deepseek-ai/DeepSeek-V3.1 | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 128,000 | 100,000 |\n| gemini-1.5-flash | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 8,192 |\n| gemini-1.5-pro | google | ✅ | ✅ | ❌ | ❌ | ❌ | 2,000,000 | 8,192 |\n| gemini-2.0-flash-exp | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,048,576 | 8,192 |\n| gemini-2.0-flash-preview-image-generation | google | ❌ | ❌ | ✅ | ❌ | ❌ | 32,000 | 8,192 |\n| gemini-2.5-flash | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,048,576 | 65,536 |\n| gemini-2.5-flash-image-preview | google | ❌ | ❌ | ✅ | ❌ | ❌ | 32,768 | 32,768 |\n| gemini-2.5-flash-lite | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,048,576 | 65,536 |\n| gemini-2.5-pro | google | ✅ | ✅ | ❌ | ❌ | ❌ | 1,048,576 | 65,536 |\n| gemini-live-2.5-flash-preview | google | ❌ | ❌ | ❌ | ❌ | ❌ | 1,048,576 | 8,192 |\n| gpt-4.1 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 32,768 |\n| gpt-4.1-mini | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 32,000 |\n| gpt-4.1-nano | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 1,000,000 | 32,000 |\n| gpt-4o | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 128,000 | 16,384 |\n| gpt-4o-mini | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 128,000 | 16,384 |\n| gpt-5-2025-08-07 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 400,000 | 128,000 |\n| gpt-5-mini-2025-08-07 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 400,000 | 128,000 |\n| gpt-5-nano-2025-08-07 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 400,000 | 128,000 |\n| meta-llama/Llama-3.3-70B-Instruct | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 8,192 | 4,096 |\n| meta-llama/Llama-4-Maverick-17B-128E-Instruct | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 1,000,000 | 100,000 |\n| meta-llama/Llama-4-Scout-17B-16E-Instruct | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 10,000,000 | 100,000 |\n| mistralai/Mistral-7B-Instruct-v0.3 | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 32,768 | 8,192 |\n| o3 | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 200,000 | 100,000 |\n| o4-mini | openai | ✅ | ✅ | ❌ | ❌ | ❌ | 200,000 | 100,000 |\n| stabilityai/stable-diffusion-3.5-large | huggingface | ❌ | ❌ | ✅ | ❌ | ❌ | - | - |\n| tokyotech-llm/Llama-3.1-Swallow-8B-Instruct-v0.5 | huggingface | ✅ | ❌ | ❌ | ❌ | ❌ | 4,096 | 1,024 |\n| veo-3.0-fast-generate-preview | google | ❌ | ❌ | ❌ | ❌ | ❌ | 1,024 | - |\n| veo-3.0-generate-preview | google | ❌ | ❌ | ❌ | ❌ | ❌ | 1,024 | - |\n| whisper-1 | openai | ❌ | ❌ | ❌ | ❌ | ✅ | - | - |'

# %% [markdown]
# ## Step 2: The Challenges - Solutions

# %% [markdown]
# ### Challenge 1 (Foundational): Generating a Simple PRD
#
# **Explanation:**
# This prompt serves as a baseline. We provide the LLM with the user stories and ask it to summarize them into a few key sections. This is a simple synthesis task that demonstrates the LLM's ability to extract and reorganize information.

# %%
simple_prd_prompt = f"""
You are a Product Manager writing a Product Requirements Document (PRD) for a new hire onboarding tool.

Use the following JSON data containing user stories as your primary source of information:
<user_stories>
{user_stories_str}
</user_stories>

Generate a PRD in markdown format with the following sections:
1. **Introduction:** A brief overview of the project's purpose.
2. **User Personas:** A summary of the key users involved.
3. **Features / User Stories:** A list of the user stories and their acceptance criteria.
"""

print("--- Generating Simple PRD ---")
if user_stories_data:
    # Enhance the prompt to improve structure and consistency
    enhanced_simple_prd_prompt = prompt_enhancer(simple_prd_prompt, model_name='gemini-2.5-pro')
    print("Enhanced Simple PRD prompt:\n", enhanced_simple_prd_prompt)
    simple_prd_output = get_completion(enhanced_simple_prd_prompt, client, model_name, api_provider)
    print(simple_prd_output)
else:
    print("Skipping PRD generation because user stories are missing.")
# Out:
# --- Generating Simple PRD ---
# 2025-10-27 20:30:03,762 ag_aisoftdev.utils INFO LLM Client configured provider=google model=gemini-2.5-pro latency_ms=None artifacts_path=None
# Enhanced Simple PRD prompt:
#  ```xml
# <persona>
# You are an expert Senior Product Manager with extensive experience creating clear, comprehensive, and actionable Product Requirements Documents (PRDs) for enterprise software. Your primary skill is synthesizing user needs from various sources into a structured and coherent document that guides the development team.
# </persona>
#
# <context>
# You are tasked with creating a PRD for a new internal software tool designed to streamline the new hire onboarding process. The primary source of requirements is a collection of user stories gathered from key stakeholders: HR Operations, Hiring Managers, and New Hires. A PRD is a formal document that defines the requirements of a product, including its purpose, features, functionality, and behavior. Your goal is to translate the provided raw user stories into a professional PRD.
# </context>
#
# <input_data>
# The following JSON object contains the user stories that will form the basis of your PRD. Analyze it carefully to understand the needs of each persona and the specific functionalities required.
#
# <user_stories_json>
# [
#   {
#     "id": 1,
#     "persona": "Chloe, the HR Operations Specialist",
#     "user_story": "As Chloe, the HR Operations Specialist, I want to automate the sending and tracking of employment documents, so that I can ensure compliance is met for every new hire and reduce my manual follow-up time.",
#     "acceptance_criteria": [
#       "Given a new hire has been created in the system, When their offer is marked as 'Accepted', Then the tool should automatically email them a link to sign their employment contract and NDA.",
#       "Given I am viewing the HR admin dashboard, When a new hire completes signing a document, Then the status for that document on my dashboard should update from 'Pending' to 'Completed' in real-time.",
#       "Given a required document has not been signed 3 days before the new hire's start date, When the system's daily check runs, Then an automated reminder email should be sent to the new hire."
#     ]
#   },
#   {
#     "id": 2,
#     "persona": "David, the Hiring Manager",
#     "user_story": "As David, the Hiring Manager, I want a collaborative tool to build a 30-60-90 day plan with my new hire, so that we can establish clear expectations and track their progress from day one.",
#     "acceptance_criteria": [
#       "Given I am viewing my new hire's profile in the onboarding tool, When I click 'Create 30-60-90 Day Plan', Then I am presented with a template containing editable sections for 30, 60, and 90-day goals.",
#       "Given I have added a goal to the 30-day section and saved the plan, When my new hire logs in and views the plan, Then they can see the goal I added and have the ability to add comments.",
#       "Given my new hire has marked a goal as 'Complete', When I view the plan, Then I should see the goal's status is updated and the overall plan progress bar has increased."
#     ]
#   },
#   {
#     "id": 3,
#     "persona": "Amelia, the New Hire",
#     "user_story": "As Amelia, the New Hire, I want to see a 'Meet the Team' page with photos and fun facts, so that I can learn about my new colleagues before my first day and feel less anxious about introductions.",
#     "acceptance_criteria": [
#       "Given I have logged into the onboarding portal, When I navigate to the 'My Team' section, Then I should see a gallery of cards, each displaying a team member's photo, name, and job title.",
#       "Given I am viewing the 'My Team' page, When I click on a team member's card, Then it should expand or link to a detailed profile showing their role description, a short bio, and fun facts.",
#       "Given my manager has assigned me to the 'Phoenix' team in the system, When I view the 'My Team' page, Then I should only see profiles for members of the 'Phoenix' team."
#     ]
#   },
#   {
#     "id": 4,
#     "persona": "David, the Hiring Manager",
#     "user_story": "As David, the Hiring Manager, I want to receive automated check-in prompts for my new hire, so that I remember to schedule regular 1:1s and can follow best practices for supporting them.",
#     "acceptance_criteria": [
#       "Given my new hire's first week is approaching, When the system date is three days before their start date, Then I should receive an email notification prompting me to schedule our first 1:1 meeting.",
#       "Given I have received a check-in prompt, When I open the email, Then it should contain a link to my calendar and a list of suggested talking points for a Week 1 check-in.",
#       "Given a new hire has been with the company for 30 days, When the system's scheduled job runs, Then both the new hire and I should receive a notification to schedule our 30-day check-in."
#     ]
#   },
#   {
#     "id": 5,
#     "persona": "Amelia, the New Hire",
#     "user_story": "As Amelia, the New Hire, I want a guided workflow to select my computer and equipment, so that my gear is ready for me on my first day and I can be productive immediately.",
#     "acceptance_criteria": [
#       "Given I have completed my initial HR paperwork, When I view my onboarding checklist, Then I should see an incomplete task named 'Select Your Equipment'.",
#       "Given I have clicked the 'Select Your Equipment' task, When the page loads, Then I am presented with a choice between available Mac or PC laptop models and a list of optional accessories.",
#       "Given I have submitted my equipment selection, When the form is processed, Then an automated ticket with my choices is created in the IT department's system and the checklist task is marked as 'Complete'."
#     ]
#   }
# ]
# </user_stories_json>
# </input_data>
#
# <instructions>
# Generate a comprehensive PRD based on the provided user stories. Follow this systematic process:
# 1.  **Synthesize the Introduction:** Read all user stories to understand the overarching problems and goals. Write a concise introduction that summarizes the purpose of the new hire onboarding tool.
# 2.  **Identify and Describe Personas:** Extract all unique user personas from the data (e.g., Chloe, David, Amelia). For each persona, write a brief, one-sentence summary of their role and primary needs based on their stories.
# 3.  **Detail Features and User Stories:** Process each user story from the JSON data one by one. For each story, create a feature section that includes the full user story and a bulleted list of its corresponding acceptance criteria.
# </instructions>
#
# <output_format>
# Structure the entire output in Markdown format. The PRD must contain the following sections, formatted exactly as described:
#
# # Product Requirements Document: New Hire Onboarding Tool
#
# ## 1. Introduction
# (A 2-3 sentence paragraph summarizing the project's purpose, the problem it solves, and its high-level goals, derived from the collective user stories.)
#
# ## 2. User Personas
# (A bulleted list of the key users. For each user, provide their name and a brief description of their role and motivation.)
# - **[Persona Name]:** [One-sentence summary of their role and needs.]
# - **[Persona Name]:** [One-sentence summary of their role and needs.]
# - ...
#
# ## 3. Features / User Stories
# (A detailed list of all features. For each feature, use a level-3 heading. State the user story clearly using bold text for the persona. Then, list all acceptance criteria as a bulleted list.)
#
# ### Feature: [Brief, descriptive title for the story, e.g., "Automated Document Management"]
# **User Story:** "As **[Persona]**, I want to **[Goal]**, so that **[Benefit]**."
# **Acceptance Criteria:**
# - [Acceptance Criterion 1]
# - [Acceptance Criterion 2]
# - [Acceptance Criterion 3]
#
# (Repeat this structure for every user story in the input data.)
# </output_format>
# ```
# # Product Requirements Document: New Hire Onboarding Tool
#
# ## 1. Introduction
# This document outlines the requirements for a new internal New Hire Onboarding Tool. The purpose of this tool is to streamline and enhance the onboarding experience for new hires, hiring managers, and HR operations. By automating manual tasks, facilitating clear goal-setting, and providing a welcoming pre-boarding experience, the tool aims to increase operational efficiency, improve new hire engagement, and ensure a productive start for every new team member.
#
# ## 2. User Personas
# - **Chloe, the HR Operations Specialist:** A detail-oriented professional who needs to automate repetitive administrative tasks to ensure compliance and reduce manual follow-up.
# - **David, the Hiring Manager:** A team leader focused on setting his new hires up for success by establishing clear expectations and providing consistent support.
# - **Amelia, the New Hire:** An incoming employee who wants a clear, guided, and welcoming experience to feel prepared and connected before her first day.
#
# ## 3. Features / User Stories
#
# ### Feature: Automated Document Management
# **User Story:** "As **Chloe, the HR Operations Specialist**, I want to automate the sending and tracking of employment documents, so that I can ensure compliance is met for every new hire and reduce my manual follow-up time."
# **Acceptance Criteria:**
# - Given a new hire has been created in the system, When their offer is marked as 'Accepted', Then the tool should automatically email them a link to sign their employment contract and NDA.
# - Given I am viewing the HR admin dashboard, When a new hire completes signing a document, Then the status for that document on my dashboard should update from 'Pending' to 'Completed' in real-time.
# - Given a required document has not been signed 3 days before the new hire's start date, When the system's daily check runs, Then an automated reminder email should be sent to the new hire.
#
# ### Feature: Collaborative 30-60-90 Day Plan
# **User Story:** "As **David, the Hiring Manager**, I want a collaborative tool to build a 30-60-90 day plan with my new hire, so that we can establish clear expectations and track their progress from day one."
# **Acceptance Criteria:**
# - Given I am viewing my new hire's profile in the onboarding tool, When I click 'Create 30-60-90 Day Plan', Then I am presented with a template containing editable sections for 30, 60, and 90-day goals.
# - Given I have added a goal to the 30-day section and saved the plan, When my new hire logs in and views the plan, Then they can see the goal I added and have the ability to add comments.
# - Given my new hire has marked a goal as 'Complete', When I view the plan, Then I should see the goal's status is updated and the overall plan progress bar has increased.
#
# ### Feature: Meet the Team Page
# **User Story:** "As **Amelia, the New Hire**, I want to see a 'Meet the Team' page with photos and fun facts, so that I can learn about my new colleagues before my first day and feel less anxious about introductions."
# **Acceptance Criteria:**
# - Given I have logged into the onboarding portal, When I navigate to the 'My Team' section, Then I should see a gallery of cards, each displaying a team member's photo, name, and job title.
# - Given I am viewing the 'My Team' page, When I click on a team member's card, Then it should expand or link to a detailed profile showing their role description, a short bio, and fun facts.
# - Given my manager has assigned me to the 'Phoenix' team in the system, When I view the 'My Team' page, Then I should only see profiles for members of the 'Phoenix' team.
#
# ### Feature: Automated Manager Check-in Prompts
# **User Story:** "As **David, the Hiring Manager**, I want to receive automated check-in prompts for my new hire, so that I remember to schedule regular 1:1s and can follow best practices for supporting them."
# **Acceptance Criteria:**
# - Given my new hire's first week is approaching, When the system date is three days before their start date, Then I should receive an email notification prompting me to schedule our first 1:1 meeting.
# - Given I have received a check-in prompt, When I open the email, Then it should contain a link to my calendar and a list of suggested talking points for a Week 1 check-in.
# - Given a new hire has been with the company for 30 days, When the system's scheduled job runs, Then both the new hire and I should receive a notification to schedule our 30-day check-in.
#
# ### Feature: Guided Equipment Selection
# **User Story:** "As **Amelia, the New Hire**, I want a guided workflow to select my computer and equipment, so that my gear is ready for me on my first day and I can be productive immediately."
# **Acceptance Criteria:**
# - Given I have completed my initial HR paperwork, When I view my onboarding checklist, Then I should see an incomplete task named 'Select Your Equipment'.
# - Given I have clicked the 'Select Your Equipment' task, When the page loads, Then I am presented with a choice between available Mac or PC laptop models and a list of optional accessories.
# - Given I have submitted my equipment selection, When the form is processed, Then an automated ticket with my choices is created in the IT department's system and the checklist task is marked as 'Complete'.

# %% [markdown]
# ### Challenge 2 (Intermediate): Generating a PRD from a Template
#
# **Explanation:**
# This is a more advanced and practical task. Providing a template gives us much greater control over the final output. The LLM's task shifts from creative writing to structured content generation. We instruct it to fill in every section, which forces it to infer logical content for sections like "Success Metrics" and "Out of Scope" based on the provided requirements. This is a powerful pattern for creating consistent documentation.

# %%
template_path = os.path.join(project_root, "templates", "prd_template.md")
if os.path.exists(template_path):
    try:
        with open(template_path, "r", encoding="utf-8") as f:
            prd_template_content = f.read()
        print(f"✅ Loaded PRD template directly from {template_path} ({len(prd_template_content)} characters)")
    except Exception as e:
        print("❌ ERROR: Failed to read template file directly:", e)
        print("   Current working directory:", os.getcwd())
        prd_template_content = ""
else:
    print("❌ ERROR: Could not find PRD template at expected path:", template_path)
    print("   Please ensure the file exists and is readable.")
    print("   Current working directory:", os.getcwd())
    prd_template_content = ""


# Build the template-based prompt
template_prd_prompt = f"""
You are a Senior Product Manager responsible for creating a detailed and formal Product Requirements Document (PRD).

Your task is to populate the provided PRD template using the information from the user stories JSON.

<prd_template>
{prd_template_content}
</prd_template>

<user_stories_json>
{user_stories_str}
</user_stories_json>

Fill out every section of the template. For sections like 'Success Metrics' or 'Out of Scope', you must infer reasonable content based on the user stories and the overall project goal of creating a new hire onboarding tool.
The final output should be the completed PRD in markdown format.
"""

print("--- Generating PRD from Template ---")
if user_stories_data and prd_template_content:
    # Enhance the template-based prompt to improve fidelity and structure
    enhanced_template_prd_prompt = prompt_enhancer(template_prd_prompt, model_name='gemini-2.5-pro')
    print("Enhanced Template PRD prompt:\n", enhanced_template_prd_prompt)
    prd_from_template_output = get_completion(enhanced_template_prd_prompt, client, model_name, api_provider)
    print(prd_from_template_output)
else:
    print("Skipping PRD generation because user stories or template are missing.")
    if not user_stories_data:
        print("   - User stories data is missing")
    if not prd_template_content:
        print("   - PRD template is missing")
    prd_from_template_output = ""
# Out:
# ✅ Loaded PRD template directly from c:\Users\647003\Desktop\repos\AG-AISOFTDEV\templates\prd_template.md (4217 characters)
# --- Generating PRD from Template ---
# 2025-10-27 20:32:09,182 ag_aisoftdev.utils INFO LLM Client configured provider=google model=gemini-2.5-pro latency_ms=None artifacts_path=None
# Enhanced Template PRD prompt:
#  <prompt>
# <persona>
# You are an expert Senior Product Manager with extensive experience creating clear, comprehensive, and actionable Product Requirements Documents (PRDs) for enterprise software. Your primary skill is synthesizing user needs into formal technical and business requirements.
# </persona>
#
# <context>
# You are tasked with creating a formal PRD for a new internal tool. The product is a **New Hire Onboarding Platform**. Your source of truth for the product's features is a JSON file containing a set of user stories. You must use these stories to populate the functional requirements and infer the content for all other sections of the PRD, such as the vision, problem statement, goals, and scope.
# </context>
#
# <input_data>
# <prd_template>
# # Product Requirements Document: [Product Name]
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | [Your Name / Team Name] |
# | **Version** | 1.0 |
# | **Last Updated** | [Date] |
#
# ## 1. Executive Summary & Vision
# *A high-level overview for stakeholders. What is this product, why are we building it, and what is the ultimate vision for its success?*
#
# [Provide a 2-3 sentence summary of the product's purpose, the core problem it solves, and the target user base. Describe the desired future state this product will enable.]
#
# ## 2. The Problem
# *A detailed look at the pain points this product will solve. This section justifies the project's existence.*
#
# **2.1. Problem Statement:**
# [Clearly and concisely describe the primary problem. Example: "New hires currently face a fragmented and overwhelming onboarding experience, leading to decreased initial productivity and a high volume of repetitive questions to HR and managers."]
#
# **2.2. User Personas & Scenarios:**
# [Summarize the key user personas affected by this problem. For each persona, describe a typical scenario they face that highlights the problem.]
#
# - **Persona 1: [e.g., The New Hire]**
# - **Persona 2: [e.g., The Hiring Manager]**
# - **Persona 3: [e.g., The HR Coordinator]**
#
# ## 3. Goals & Success Metrics
# *How will we measure success? This section defines the specific, measurable outcomes we expect.*
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Improve New Hire Efficiency | Reduce time-to-first-contribution | Decrease by 20% in Q1 |
# | Reduce Support Load | Decrease repetitive questions to HR | 30% reduction in support tickets |
# | Increase Engagement | Onboarding completion rate | Achieve 95% completion rate |
#
# ## 4. Functional Requirements & User Stories
# *The core of the PRD. This section details what the product must do, broken down into actionable user stories.*
#
# [This section will be populated by the AI based on the JSON artifact. The structure should follow standard Agile user story format.]
#
# ---
# _Example Epic: User Authentication_
#
# * **Story 1.1:** As a New Hire, I want to log in with my company credentials, so that I can access the onboarding platform securely.
#     * **Acceptance Criteria:**
#         * **Given** I am on the login page, **when** I enter my valid SSO credentials, **then** I am redirected to my personal dashboard.
#         * **Given** I am on the login page, **when** I enter invalid credentials, **then** I see a clear error message.
# ---
#
# ## 5. Non-Functional Requirements (NFRs)
# *The qualities of the system. These are just as important as the functional requirements.*
#
# - **Performance:** The application must load in under 3 seconds on a standard corporate network connection.
# - **Security:** All data must be encrypted in transit and at rest. The system must comply with company SSO policies.
# - **Accessibility:** The user interface must be compliant with WCAG 2.1 AA standards.
# - **Scalability:** The system must support up to 500 concurrent users during peak onboarding seasons.
#
# ## 6. Release Plan & Milestones
# *A high-level timeline for delivery.*
#
# - **Version 1.0 (MVP):** [Target Date] - Core features including user login, task checklist, and document repository.
# - **Version 1.1:** [Target Date] - Mentorship connection and team introduction features.
# - **Version 2.0:** [Target Date] - Full social engagement and gamification elements.
#
# ## 7. Out of Scope & Future Considerations
# *What this product is **not**. This section is critical for managing expectations and preventing scope creep.*
#
# **7.1. Out of Scope for V1.0:**
# - Direct integration with third-party HR payroll systems.
# - A native mobile application (the web app will be mobile-responsive).
# - Advanced analytics dashboard for managers.
#
# **7.2. Future Work:**
# - Integration with the corporate Learning Management System (LMS).
# - AI-powered personalized learning paths for new hires.
#
# ## 8. Appendix & Open Questions
# *A place to track dependencies, assumptions, and questions that need answers.*
#
# - **Open Question:** Which team will be responsible for maintaining the content in the document repository?
# - **Dependency:** The final UI design mockups are required from the Design team by [Date].
# </prd_template>
#
# <user_stories_json>
# [
#   {
#     "id": 1,
#     "persona": "Chloe, the HR Operations Specialist",
#     "user_story": "As Chloe, the HR Operations Specialist, I want to automate the sending and tracking of employment documents, so that I can ensure compliance is met for every new hire and reduce my manual follow-up time.",
#     "acceptance_criteria": [
#       "Given a new hire has been created in the system, When their offer is marked as 'Accepted', Then the tool should automatically email them a link to sign their employment contract and NDA.",
#       "Given I am viewing the HR admin dashboard, When a new hire completes signing a document, Then the status for that document on my dashboard should update from 'Pending' to 'Completed' in real-time.",
#       "Given a required document has not been signed 3 days before the new hire's start date, When the system's daily check runs, Then an automated reminder email should be sent to the new hire."
#     ]
#   },
#   {
#     "id": 2,
#     "persona": "David, the Hiring Manager",
#     "user_story": "As David, the Hiring Manager, I want a collaborative tool to build a 30-60-90 day plan with my new hire, so that we can establish clear expectations and track their progress from day one.",
#     "acceptance_criteria": [
#       "Given I am viewing my new hire's profile in the onboarding tool, When I click 'Create 30-60-90 Day Plan', Then I am presented with a template containing editable sections for 30, 60, and 90-day goals.",
#       "Given I have added a goal to the 30-day section and saved the plan, When my new hire logs in and views the plan, Then they can see the goal I added and have the ability to add comments.",
#       "Given my new hire has marked a goal as 'Complete', When I view the plan, Then I should see the goal's status is updated and the overall plan progress bar has increased."
#     ]
#   },
#   {
#     "id": 3,
#     "persona": "Amelia, the New Hire",
#     "user_story": "As Amelia, the New Hire, I want to see a 'Meet the Team' page with photos and fun facts, so that I can learn about my new colleagues before my first day and feel less anxious about introductions.",
#     "acceptance_criteria": [
#       "Given I have logged into the onboarding portal, When I navigate to the 'My Team' section, Then I should see a gallery of cards, each displaying a team member's photo, name, and job title.",
#       "Given I am viewing the 'My Team' page, When I click on a team member's card, Then it should expand or link to a detailed profile showing their role description, a short bio, and fun facts.",
#       "Given my manager has assigned me to the 'Phoenix' team in the system, When I view the 'My Team' page, Then I should only see profiles for members of the 'Phoenix' team."
#     ]
#   },
#   {
#     "id": 4,
#     "persona": "David, the Hiring Manager",
#     "user_story": "As David, the Hiring Manager, I want to receive automated check-in prompts for my new hire, so that I remember to schedule regular 1:1s and can follow best practices for supporting them.",
#     "acceptance_criteria": [
#       "Given my new hire's first week is approaching, When the system date is three days before their start date, Then I should receive an email notification prompting me to schedule our first 1:1 meeting.",
#       "Given I have received a check-in prompt, When I open the email, Then it should contain a link to my calendar and a list of suggested talking points for a Week 1 check-in.",
#       "Given a new hire has been with the company for 30 days, When the system's scheduled job runs, Then both the new hire and I should receive a notification to schedule our 30-day check-in."
#     ]
#   },
#   {
#     "id": 5,
#     "persona": "Amelia, the New Hire",
#     "user_story": "As Amelia, the New Hire, I want a guided workflow to select my computer and equipment, so that my gear is ready for me on my first day and I can be productive immediately.",
#     "acceptance_criteria": [
#       "Given I have completed my initial HR paperwork, When I view my onboarding checklist, Then I should see an incomplete task named 'Select Your Equipment'.",
#       "Given I have clicked the 'Select Your Equipment' task, When the page loads, Then I am presented with a choice between available Mac or PC laptop models and a list of optional accessories.",
#       "Given I have submitted my equipment selection, When the form is processed, Then an automated ticket with my choices is created in the IT department's system and the checklist task is marked as 'Complete'."
#     ]
#   }
# ]
# </user_stories_json>
# </input_data>
#
# <instructions>
# Follow these steps to generate the complete PRD:
#
# 1.  **Analyze and Synthesize:** First, thoroughly analyze the provided `<user_stories_json>`. Identify the key themes, user personas (New Hire, Hiring Manager, HR Specialist), and the core problems being solved (manual processes, lack of clarity, new hire anxiety).
# 2.  **Infer and Populate Non-Functional Sections:** Based on your analysis, logically deduce the content for all sections of the PRD *except* for Section 4.
#     *   For the header, invent a product name like "Project Horizon: New Hire Onboarding Platform" and use placeholder names/dates.
#     *   For the **Executive Summary**, create a concise overview of the platform's purpose.
#     *   For **The Problem**, articulate the pain points for each identified persona.
#     *   For **Goals & Success Metrics**, define specific, measurable targets that directly relate to the problems solved in the user stories (e.g., reducing HR's manual work, improving new hire preparedness).
#     *   For **Non-Functional Requirements**, infer requirements based on the stories. For example, the document signing story implies a need for high security and reliability. The equipment selection story implies a need for integration with an IT ticketing system.
#     *   For the **Release Plan** and **Out of Scope** sections, create a logical roadmap. The features from the user stories should constitute the MVP (Version 1.0).
# 3.  **Populate Functional Requirements:** Transcribe the user stories from the JSON into Section 4 of the PRD. Group the stories by persona or create logical epics. Format each story and its acceptance criteria exactly as shown in the template's example.
# 4.  **Final Review:** Ensure every section of the template is filled out completely. The final document should be a single, cohesive, and professional PRD in Markdown format.
# </instructions>
#
# <output_specification>
# - **Format:** A single, complete Markdown document.
# - **Tone:** Formal, professional, and authoritative, suitable for a corporate stakeholder audience.
# - **Content:** All content must be directly derived or logically inferred from the provided user stories. Do not invent features or requirements that are not supported by the source data.
# - **Completeness:** Do not leave any sections of the PRD template blank.
# </output_specification>
# </prompt>
# # Product Requirements Document: Project Horizon - New Hire Onboarding Platform
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | Product Management |
# | **Version** | 1.0 |
# | **Last Updated** | 2023-10-27 |
#
# ## 1. Executive Summary & Vision
# Project Horizon is a centralized, internal platform designed to streamline and enrich the new hire onboarding experience. It addresses the currently fragmented and manual processes by providing a single source of truth for new hires, their managers, and HR coordinators. The vision for Project Horizon is to create a welcoming, efficient, and consistent onboarding journey that accelerates a new hire's time-to-productivity and fosters a greater sense of belonging from day one.
#
# ## 2. The Problem
# A successful onboarding process is critical for employee retention and long-term success, yet our current approach is inefficient and inconsistent. It creates significant administrative overhead, leaves new hires feeling overwhelmed, and prevents managers from effectively supporting their new team members.
#
# **2.1. Problem Statement:**
# New hires currently face a disconnected and confusing onboarding process, leading to anxiety and delayed productivity. Concurrently, HR and Hiring Managers are burdened with manual, repetitive tasks, resulting in inconsistent experiences and potential compliance risks.
#
# **2.2. User Personas & Scenarios:**
# [Summarize the key user personas affected by this problem. For each persona, describe a typical scenario they face that highlights the problem.]
#
# - **Persona 1: Amelia, The New Hire**
#   - **Scenario:** Amelia has just accepted her offer. She receives multiple emails from different departments with forms to sign, people to meet, and tasks to complete. She feels overwhelmed, isn't sure who her teammates are, and worries that her laptop won't be ready for her on her first day, causing anxiety before she even starts.
#
# - **Persona 2: David, The Hiring Manager**
#   - **Scenario:** David is excited about his new hire, Amelia, starting. However, he's juggling his regular duties and forgets to schedule a crucial first-week check-in. He also hasn't had time to formalize a 30-day plan, leading to a lack of clear expectations for Amelia in her first month.
#
# - **Persona 3: Chloe, The HR Operations Specialist**
#   - **Scenario:** Chloe is responsible for ensuring all new hires complete their employment contracts and NDAs before their start date. She spends several hours each week manually tracking document statuses in a spreadsheet and sending reminder emails, taking time away from more strategic HR initiatives.
#
# ## 3. Goals & Success Metrics
# *How will we measure success? This section defines the specific, measurable outcomes we expect.*
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Reduce HR Administrative Load | Reduction in manual hours spent by HR on document follow-up per hire. | Decrease by 40% within 6 months. |
# | Improve New Hire Preparedness | Percentage of new hires with all required equipment on Day 1. | Achieve 98% readiness. |
# | Enhance Manager Effectiveness | Manager compliance with scheduled check-in prompts (Day 3, Day 30). | Achieve 90% compliance rate. |
# | Increase New Hire Engagement | Onboarding task completion rate within the platform. | Achieve 95% completion rate. |
#
# ## 4. Functional Requirements & User Stories
# *The core of the PRD. This section details what the product must do, broken down into actionable user stories.*
#
# ---
# ### Epic: HR & Compliance Automation
#
# *   **Story 1.1:** As Chloe, the HR Operations Specialist, I want to automate the sending and tracking of employment documents, so that I can ensure compliance is met for every new hire and reduce my manual follow-up time.
#     *   **Acceptance Criteria:**
#         *   **Given** a new hire has been created in the system, **when** their offer is marked as 'Accepted', **then** the tool should automatically email them a link to sign their employment contract and NDA.
#         *   **Given** I am viewing the HR admin dashboard, **when** a new hire completes signing a document, **then** the status for that document on my dashboard should update from 'Pending' to 'Completed' in real-time.
#         *   **Given** a required document has not been signed 3 days before the new hire's start date, **when** the system's daily check runs, **then** an automated reminder email should be sent to the new hire.
#
# ---
# ### Epic: Manager Enablement
#
# *   **Story 2.1:** As David, the Hiring Manager, I want a collaborative tool to build a 30-60-90 day plan with my new hire, so that we can establish clear expectations and track their progress from day one.
#     *   **Acceptance Criteria:**
#         *   **Given** I am viewing my new hire's profile in the onboarding tool, **when** I click 'Create 30-60-90 Day Plan', **then** I am presented with a template containing editable sections for 30, 60, and 90-day goals.
#         *   **Given** I have added a goal to the 30-day section and saved the plan, **when** my new hire logs in and views the plan, **then** they can see the goal I added and have the ability to add comments.
#         *   **Given** my new hire has marked a goal as 'Complete', **when** I view the plan, **then** I should see the goal's status is updated and the overall plan progress bar has increased.
#
# *   **Story 2.2:** As David, the Hiring Manager, I want to receive automated check-in prompts for my new hire, so that I remember to schedule regular 1:1s and can follow best practices for supporting them.
#     *   **Acceptance Criteria:**
#         *   **Given** my new hire's first week is approaching, **when** the system date is three days before their start date, **then** I should receive an email notification prompting me to schedule our first 1:1 meeting.
#         *   **Given** I have received a check-in prompt, **when** I open the email, **then** it should contain a link to my calendar and a list of suggested talking points for a Week 1 check-in.
#         *   **Given** a new hire has been with the company for 30 days, **when** the system's scheduled job runs, **then** both the new hire and I should receive a notification to schedule our 30-day check-in.
#
# ---
# ### Epic: New Hire Experience
#
# *   **Story 3.1:** As Amelia, the New Hire, I want a guided workflow to select my computer and equipment, so that my gear is ready for me on my first day and I can be productive immediately.
#     *   **Acceptance Criteria:**
#         *   **Given** I have completed my initial HR paperwork, **when** I view my onboarding checklist, **then** I should see an incomplete task named 'Select Your Equipment'.
#         *   **Given** I have clicked the 'Select Your Equipment' task, **when** the page loads, **then** I am presented with a choice between available Mac or PC laptop models and a list of optional accessories.
#         *   **Given** I have submitted my equipment selection, **when** the form is processed, **then** an automated ticket with my choices is created in the IT department's system and the checklist task is marked as 'Complete'.
#
# *   **Story 3.2:** As Amelia, the New Hire, I want to see a 'Meet the Team' page with photos and fun facts, so that I can learn about my new colleagues before my first day and feel less anxious about introductions.
#     *   **Acceptance Criteria:**
#         *   **Given** I have logged into the onboarding portal, **when** I navigate to the 'My Team' section, **then** I should see a gallery of cards, each displaying a team member's photo, name, and job title.
#         *   **Given** I am viewing the 'My Team' page, **when** I click on a team member's card, **then** it should expand or link to a detailed profile showing their role description, a short bio, and fun facts.
#         *   **Given** my manager has assigned me to the 'Phoenix' team in the system, **when** I view the 'My Team' page, **then** I should only see profiles for members of the 'Phoenix' team.
#
# ---
#
# ## 5. Non-Functional Requirements (NFRs)
# *The qualities of the system. These are just as important as the functional requirements.*
#
# - **Performance:** The application must load in under 3 seconds on a standard corporate network connection. All user-facing interactions must respond in under 200ms.
# - **Security:** All data, especially Personally Identifiable Information (PII) and employment documents, must be encrypted in transit (TLS 1.2+) and at rest (AES-256). The system must comply with company SSO policies for authentication.
# - **Accessibility:** The user interface must be compliant with Web Content Accessibility Guidelines (WCAG) 2.1 AA standards to ensure usability for all employees.
# - **Scalability:** The system must support up to 500 concurrent users during peak onboarding seasons (e.g., post-university graduation hiring) without performance degradation.
# - **Integrations:** The system must integrate with the IT department's ticketing system (e.g., Jira, ServiceNow) via a stable API to automate equipment requests.
#
# ## 6. Release Plan & Milestones
# *A high-level timeline for delivery.*
#
# - **Version 1.0 (MVP):** [Target Date: End of Q2] - Core features required for a complete onboarding journey:
#     - User authentication via SSO.
#     - Automated document sending and tracking for HR.
#     - Guided equipment selection workflow for new hires.
#     - "Meet the Team" page.
#     - Collaborative 30-60-90 day planning tool.
#     - Automated check-in reminders for managers.
#
# - **Version 1.1:** [Target Date: End of Q3] - Enhancements based on V1.0 feedback:
#     - Mentorship connection feature.
#     - Expanded resource library and company FAQs.
#
# - **Version 2.0:** [Target Date: Q1 Next Year] - Advanced engagement and analytics:
#     - Full social engagement features (e.g., welcome messages on a team feed).
#     - Gamification elements (e.g., badges for task completion).
#     - Analytics dashboard for managers and HR to track onboarding effectiveness.
#
# ## 7. Out of Scope & Future Considerations
# *What this product is **not**. This section is critical for managing expectations and preventing scope creep.*
#
# **7.1. Out of Scope for V1.0:**
# - Direct integration with third-party HR payroll systems (e.g., ADP, Workday).
# - A native mobile application (the web application will be mobile-responsive).
# - Performance management or formal review functionality beyond the 30-60-90 day plan.
# - Customizable onboarding plans per department or role.
#
# **7.2. Future Work:**
# - Integration with the corporate Learning Management System (LMS) to assign role-specific training.
# - AI-powered personalized onboarding paths based on role and experience level.
# - Integration with company-wide communication tools (e.g., Slack, Teams) for notifications.
#
# ## 8. Appendix & Open Questions
# *A place to track dependencies, assumptions, and questions that need answers.*
#
# - **Open Question:** What are the technical specifications for the API to create tickets in the IT service management system?
# - **Open Question:** Who is responsible for populating and maintaining the 'Meet the Team' profile content (bios, fun facts)?
# - **Dependency:** The final UI/UX designs and mockups are required from the Design team by [Date: 2 weeks from kickoff].
# - **Assumption:** The company's SSO provider can be used for authentication for all user types (internal employees and pre-start new hires).

# %%
# Diagnostic: Check template file existence and path resolution
print("=== TEMPLATE DIAGNOSTIC ===")
print("Current working directory:", os.getcwd())

# Check if templates directory exists
templates_dir = os.path.join(project_root, "templates")
print(f"Project root: {project_root}")
print(f"Templates directory: {templates_dir}")
print(f"Templates directory exists: {os.path.exists(templates_dir)}")

if os.path.exists(templates_dir):
    print("Contents of templates directory:")
    for item in os.listdir(templates_dir):
        full_path = os.path.join(templates_dir, item)
        print(f"  - {item} ({'file' if os.path.isfile(full_path) else 'directory'})")

# Check the specific template file
template_file = os.path.join(project_root, "templates", "prd_template.md")
print(f"\nPRD template file path: {template_file}")
print(f"PRD template file exists: {os.path.exists(template_file)}")

if os.path.exists(template_file):
    print(f"File size: {os.path.getsize(template_file)} bytes")
else:
    print("❌ Template file not found!")
    
print("==========================")
# Out:
# === TEMPLATE DIAGNOSTIC ===
# Current working directory: c:\Users\647003\Desktop\repos\AG-AISOFTDEV\Solutions\Day_01_Planning_and_Requirements
# Project root: c:\Users\647003\Desktop\repos\AG-AISOFTDEV
# Templates directory: c:\Users\647003\Desktop\repos\AG-AISOFTDEV\templates
# Templates directory exists: True
# Contents of templates directory:
#   - adr_template.md (file)
#   - prd_template.md (file)
#
# PRD template file path: c:\Users\647003\Desktop\repos\AG-AISOFTDEV\templates\prd_template.md
# PRD template file exists: True
# File size: 4297 bytes
# ==========================

# %% [markdown]
# ### Challenge 3 (Advanced): Programmatic Validation with Pydantic
#
# **Explanation:**
# This is the most advanced challenge. We are now using an LLM to write *code that validates documents*. Generating a Pydantic model turns our document's structure into a testable, code-based standard. This is a form of 'documentation-as-code' that allows for automated governance, ensuring all future PRDs conform to the same reliable format.
#
# 1.  **Prompting for Code:** We give the LLM the PRD template and ask it to generate a Pydantic model. Pydantic is a data validation library, and using it to define our document structure turns that structure into a testable, reusable standard.
# 2.  **Saving the Model:** We save the generated Python code to a specific location (`app/validation_models/prd_model.py`). This isn't just a temporary script; it's a formal part of our application's codebase, intended to be used for future validation tasks.
# 3.  **Saving the PRD:** Finally, we save the markdown PRD generated in the intermediate step. This becomes the official `day1_prd.md` artifact for our project.

# %%
pydantic_model_prompt = f"""
You are a Python developer specializing in data validation with Pydantic.

Based on the following markdown PRD template, generate a single Pydantic model class named `ProductRequirementsDocument` that represents its structure.

<prd_template>
{prd_template_content}
</prd_template>

The model should have fields that correspond to the main sections of the template. Use appropriate Python types (e.g., str, List, Dict) from the `typing` library.
Ensure you include the necessary imports from `pydantic` and `typing`.
Only output the raw Python code for the model, without any explanation.
"""

print("--- Generating Pydantic Model for PRD ---")

if prd_template_content:
    # Enhance the prompt to encourage precise, import-ready Python code
    enhanced_pydantic_model_prompt = prompt_enhancer(pydantic_model_prompt, model_name='gemini-2.5-pro')
    print("Enhanced Pydantic Model prompt:\n", enhanced_pydantic_model_prompt)
    pydantic_model_code = get_completion(enhanced_pydantic_model_prompt, client, model_name, api_provider)
    
    if pydantic_model_code:
        # Use our standardized cleaning function
        cleaned_code = clean_llm_output(pydantic_model_code, language='python')
        
        print("\n--- Generated Pydantic Model ---")
        print(cleaned_code)

        # Save the generated Pydantic model code to a file.
        model_path = "app/validation_models/prd_model.py"
        save_artifact(cleaned_code, model_path, overwrite=True)
    else:
        print("Warning: Pydantic model generation failed, get_completion returned None.")
else:
    print("Skipping Pydantic model generation because template is missing.")

# Finally, save the completed PRD from the intermediate challenge as our official artifact
if prd_from_template_output:
    save_artifact(prd_from_template_output, "day1_prd.md", overwrite=True)
# Out:
# --- Generating Pydantic Model for PRD ---
# 2025-10-27 20:34:52,296 ag_aisoftdev.utils INFO LLM Client configured provider=google model=gemini-2.5-pro latency_ms=None artifacts_path=None
# Enhanced Pydantic Model prompt:
#  ```xml
# <persona>
# You are an expert Python developer and a leading authority on data modeling with Pydantic. You specialize in creating robust, type-safe, and well-structured data models that accurately represent complex, semi-structured documents. Your code is clean, idiomatic, and follows best practices for data validation and serialization.
# </persona>
#
# <objective>
# Your task is to analyze the provided markdown template for a Product Requirements Document (PRD) and generate a single, comprehensive Pydantic model class named `ProductRequirementsDocument` that perfectly represents its structure.
# </objective>
#
# <context>
# Here is the markdown template for the Product Requirements Document.
# <prd_template>
# # Product Requirements Document: [Product Name]
#
# | Status | **Draft** |
# | :--- | :--- |
# | **Author** | [Your Name / Team Name] |
# | **Version** | 1.0 |
# | **Last Updated** | [Date] |
#
# ## 1. Executive Summary & Vision
# *A high-level overview for stakeholders. What is this product, why are we building it, and what is the ultimate vision for its success?*
#
# [Provide a 2-3 sentence summary of the product's purpose, the core problem it solves, and the target user base. Describe the desired future state this product will enable.]
#
# ## 2. The Problem
# *A detailed look at the pain points this product will solve. This section justifies the project's existence.*
#
# **2.1. Problem Statement:**
# [Clearly and concisely describe the primary problem. Example: "New hires currently face a fragmented and overwhelming onboarding experience, leading to decreased initial productivity and a high volume of repetitive questions to HR and managers."]
#
# **2.2. User Personas & Scenarios:**
# [Summarize the key user personas affected by this problem. For each persona, describe a typical scenario they face that highlights the problem.]
#
# - **Persona 1: [e.g., The New Hire]**
# - **Persona 2: [e.g., The Hiring Manager]**
# - **Persona 3: [e.g., The HR Coordinator]**
#
# ## 3. Goals & Success Metrics
# *How will we measure success? This section defines the specific, measurable outcomes we expect.*
#
# | Goal | Key Performance Indicator (KPI) | Target |
# | :--- | :--- | :--- |
# | Improve New Hire Efficiency | Reduce time-to-first-contribution | Decrease by 20% in Q1 |
# | Reduce Support Load | Decrease repetitive questions to HR | 30% reduction in support tickets |
# | Increase Engagement | Onboarding completion rate | Achieve 95% completion rate |
#
# ## 4. Functional Requirements & User Stories
# *The core of the PRD. This section details what the product must do, broken down into actionable user stories.*
#
# [This section will be populated by the AI based on the JSON artifact from Lab 1. The structure should follow standard Agile user story format.]
#
# ---
# _Example Epic: User Authentication_
#
# * **Story 1.1:** As a New Hire, I want to log in with my company credentials, so that I can access the onboarding platform securely.
#     * **Acceptance Criteria:**
#         * **Given** I am on the login page, **when** I enter my valid SSO credentials, **then** I am redirected to my personal dashboard.
#         * **Given** I am on the login page, **when** I enter invalid credentials, **then** I see a clear error message.
# ---
#
# ## 5. Non-Functional Requirements (NFRs)
# *The qualities of the system. These are just as important as the functional requirements.*
#
# - **Performance:** The application must load in under 3 seconds on a standard corporate network connection.
# - **Security:** All data must be encrypted in transit and at rest. The system must comply with company SSO policies.
# - **Accessibility:** The user interface must be compliant with WCAG 2.1 AA standards.
# - **Scalability:** The system must support up to 500 concurrent users during peak onboarding seasons.
#
# ## 6. Release Plan & Milestones
# *A high-level timeline for delivery.*
#
# - **Version 1.0 (MVP):** [Target Date] - Core features including user login, task checklist, and document repository.
# - **Version 1.1:** [Target Date] - Mentorship connection and team introduction features.
# - **Version 2.0:** [Target Date] - Full social engagement and gamification elements.
#
# ## 7. Out of Scope & Future Considerations
# *What this product is **not**. This section is critical for managing expectations and preventing scope creep.*
#
# **7.1. Out of Scope for V1.0:**
# - Direct integration with third-party HR payroll systems.
# - A native mobile application (the web app will be mobile-responsive).
# - Advanced analytics dashboard for managers.
#
# **7.2. Future Work:**
# - Integration with the corporate Learning Management System (LMS).
# - AI-powered personalized learning paths for new hires.
#
# ## 8. Appendix & Open Questions
# *A place to track dependencies, assumptions, and questions that need answers.*
#
# - **Open Question:** Which team will be responsible for maintaining the content in the document repository?
# - **Dependency:** The final UI design mockups are required from the Design team by [Date].
# </prd_template>
# </context>
#
# <instructions>
# Follow these steps to construct the Pydantic model:
#
# 1.  **Analyze the PRD Structure:** Systematically parse the markdown template, identifying all major sections, subsections, tables, and lists.
# 2.  **Define Nested Models for Structured Data:** For any section that contains a clear, repeatable structure (like a table or a set of related fields), create a dedicated nested Pydantic `BaseModel`. This is critical for creating a clean, modular, and maintainable model.
#     *   The header table (`Status`, `Author`, etc.) should be a nested model.
#     -   The "Problem" section has distinct subsections and should be a nested model.
#     *   The "Goals & Success Metrics" table is a perfect candidate for a `List` of a custom nested model.
#     *   The "Functional Requirements" section, with its `Epic`, `Story`, and `Acceptance Criteria` structure, requires nested models.
#     *   The "Out of Scope" and "Appendix" sections, with their distinct subsections, should also be modeled as nested classes.
# 3.  **Select Precise Types:** For each field, choose the most appropriate Python type from the `typing` and `datetime` libraries. Use `str` for text, `List[str]` for simple bulleted lists, `datetime.date` for dates, and your custom nested models for complex objects. Use `Optional` for fields that may not be present.
# 4.  **Assemble the Main Model:** Combine all the fields and nested models into the final `ProductRequirementsDocument` class.
# 5.  **Include All Necessary Imports:** Ensure the final code block begins with all required imports from `pydantic`, `typing`, and `datetime`.
# </instructions>
#
# <example>
# To guide your modeling of the table structure, consider this best-practice example for the "Goals & Success Metrics" section. Notice the use of a nested model within a `List` and the `Field` alias to handle the complex column header.
#
# ```python
# from pydantic import BaseModel, Field
# from typing import List
#
# class GoalMetric(BaseModel):
#     goal: str = Field(..., description="The high-level objective.")
#     kpi: str = Field(..., alias="Key Performance Indicator (KPI)", description="The specific metric to track.")
#     target: str = Field(..., description="The desired value or outcome for the KPI.")
#
# class ExampleModel(BaseModel):
#     goals_and_success_metrics: List[GoalMetric]
# ```
# </example>
#
# <output_specification>
# - Generate only the raw Python code for the complete Pydantic model.
# - The main class must be named `ProductRequirementsDocument`.
# - Do not include any explanations, comments (other than docstrings or `description` in `Field`), or markdown formatting in your output.
# - The code must be a single, complete, and runnable block.
# </output_specification>
# ```
#
# --- Generated Pydantic Model ---
# from datetime import date
# from typing import List, Optional
#
# from pydantic import BaseModel, Field
#
#
# class Metadata(BaseModel):
#     """
#     Represents the document's header information.
#     """
#     status: str = Field(..., description="The current status of the document (e.g., Draft, In Review, Approved).")
#     author: str = Field(..., description="The name of the author or team responsible for the document.")
#     version: str = Field(..., description="The version number of the document, e.g., '1.0'.")
#     last_updated: date = Field(..., alias="Last Updated", description="The date the document was last modified.")
#
#
# class ProblemDefinition(BaseModel):
#     """
#     Defines the problem the product aims to solve, including user context.
#     """
#     problem_statement: str = Field(..., description="A clear and concise description of the primary problem.")
#     user_personas_and_scenarios: List[str] = Field(
#         ...,
#         description="A list of key user personas affected by the problem and their typical scenarios."
#     )
#
#
# class GoalMetric(BaseModel):
#     """
#     A specific, measurable goal with its corresponding success metric and target.
#     """
#     goal: str = Field(..., description="The high-level objective.")
#     kpi: str = Field(..., alias="Key Performance Indicator (KPI)", description="The specific metric to track.")
#     target: str = Field(..., description="The desired value or outcome for the KPI.")
#
#
# class UserStory(BaseModel):
#     """
#     Represents a single user story with its acceptance criteria.
#     """
#     story: str = Field(..., description="The user story in the format 'As a [persona], I want [action], so that [benefit]'.")
#     acceptance_criteria: List[str] = Field(
#         ...,
#         description="A list of conditions that must be met for the story to be considered complete."
#     )
#
#
# class Epic(BaseModel):
#     """
#     A collection of related user stories that represent a larger feature.
#     """
#     title: str = Field(..., description="The title of the epic, e.g., 'User Authentication'.")
#     stories: List[UserStory] = Field(..., description="A list of user stories belonging to this epic.")
#
#
# class NonFunctionalRequirements(BaseModel):
#     """
#     Defines the quality attributes and constraints of the system.
#     """
#     performance: str = Field(..., description="Requirements related to system speed and responsiveness.")
#     security: str = Field(..., description="Requirements related to data protection and access control.")
#     accessibility: str = Field(..., description="Requirements for usability by people with disabilities (e.g., WCAG standards).")
#     scalability: str = Field(..., description="Requirements for the system's ability to handle load.")
#
#
# class Milestone(BaseModel):
#     """
#     A significant point or event in the project's timeline.
#     """
#     version: str = Field(..., description="The name or version of the release, e.g., 'Version 1.0 (MVP)'.")
#     target_date: date = Field(..., description="The planned delivery date for this milestone.")
#     description: str = Field(..., description="A summary of the features and capabilities included in this milestone.")
#
#
# class Scope(BaseModel):
#     """
#     Clarifies what is and is not included in the project, especially for the initial release.
#     """
#     out_of_scope_for_v1: List[str] = Field(..., description="A list of features explicitly excluded from the first version.")
#     future_work: List[str] = Field(..., description="A list of potential features or integrations for future consideration.")
#
#
# class AppendixItem(BaseModel):
#     """
#     An item in the appendix, such as an open question, dependency, or assumption.
#     """
#     item_type: str = Field(..., description="The category of the item, e.g., 'Open Question', 'Dependency'.")
#     description: str = Field(..., description="The detailed text of the question, dependency, or note.")
#
#
# class ProductRequirementsDocument(BaseModel):
#     """
#     A comprehensive Pydantic model representing a Product Requirements Document (PRD).
#     """
#     product_name: str = Field(..., description="The name of the product this PRD describes.")
#     metadata: Metadata = Field(..., description="High-level metadata about the document.")
#     executive_summary_and_vision: str = Field(
#         ...,
#         description="A high-level overview of the product, its purpose, and its vision for success."
#     )
#     problem: ProblemDefinition = Field(
#         ...,
#         alias="The Problem",
#         description="A detailed look at the pain points this product will solve."
#     )
#     goals_and_success_metrics: List[GoalMetric] = Field(
#         ...,
#         alias="Goals & Success Metrics",
#         description="Specific, measurable outcomes to determine the product's success."
#     )
#     functional_requirements: List[Epic] = Field(
#         ...,
#         alias="Functional Requirements & User Stories",
#         description="A breakdown of what the product must do, structured as epics and user stories."
#     )
#     non_functional_requirements: NonFunctionalRequirements = Field(
#         ...,
#         alias="Non-Functional Requirements (NFRs)",
#         description="The quality attributes of the system, such as performance, security, and accessibility."
#     )
#     release_plan: List[Milestone] = Field(
#         ...,
#         alias="Release Plan & Milestones",
#         description="A high-level timeline for delivery, broken down into major versions or milestones."
#     )
#     scope: Scope = Field(
#         ...,
#         alias="Out of Scope & Future Considerations",
#         description="Defines the boundaries of the project to manage expectations and prevent scope creep."
#     )
#     appendix: List[AppendixItem] = Field(
#         ...,
#         alias="Appendix & Open Questions",
#         description="A section for tracking dependencies, assumptions, and unresolved questions."
#     )

# %% [markdown]
# ## Lab Conclusion
#
# Excellent work! You have now taken the structured user stories from the first lab and synthesized them into a formal Product Requirements Document. You also created a Pydantic model to enforce the structure of this document, introducing automated governance into your workflow. The `day1_prd.md` artifact will be the primary input for Day 2, where we will begin designing our system's architecture and database.
#
# > **Key Takeaway:** Using an LLM to populate a pre-defined template is a powerful pattern for creating consistent, high-quality documentation at scale. It combines the LLM's language skills with your required structure.
